# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path_file = f'loan_data_total.csv'
df_loan = pd.read_csv(path_file, sep=';', low_memory=False)

# %%
# Lista completa
variaveis_explicativas = [
    "valor_financiado",
    "finalidade_emprestimo",  # categórica (não entra)
    "taxa_juros",
    "valor_parcela",
    "tempo_relacionamento",
    "escore_fico",
    "inadimplencia_2anos",
    "registros_publicos_negativos",
    "renda_mensal",
    "compm_renda"
]

# Selecionar apenas variáveis numéricas
variaveis_numericas = [
    "valor_financiado",
    "taxa_juros",
    "valor_parcela",
    "tempo_relacionamento",
    "escore_fico",
    "inadimplencia_2_anos",
    "registros_publicos_negativos",
    "renda_mensal",
]

df_corr = df_loan[variaveis_numericas].dropna()

# Matriz de correlação de Pearson
matriz_corr = df_corr.corr(method="pearson")

# Exibir no console
print(matriz_corr.round(3))
# Out:
#                               valor_financiado  taxa_juros  valor_parcela  \
# valor_financiado                         1.000      -0.089          0.993
# taxa_juros                              -0.089       1.000          0.006
# valor_parcela                            0.993       0.006          1.000
# tempo_relacionamento                     0.151      -0.136          0.138
# escore_fico                              0.102      -0.453          0.059
# inadimplencia_2_anos                    -0.009       0.075         -0.001
# registros_publicos_negativos            -0.055       0.052         -0.049
# renda_mensal                             0.257      -0.082          0.248
#
#                               tempo_relacionamento  escore_fico  \
# valor_financiado                             0.151        0.102
# taxa_juros                                  -0.136       -0.453
# valor_parcela                                0.138        0.059
# tempo_relacionamento                         1.000        0.113
# escore_fico                                  0.113        1.000
# inadimplencia_2_anos                         0.086       -0.178
# registros_publicos_negativos                 0.063       -0.184
# renda_mensal                                 0.119        0.048
#
#                               inadimplencia_2_anos  \
# valor_financiado                            -0.009
# taxa_juros                                   0.075
# valor_parcela                               -0.001
# tempo_relacionamento                         0.086
# escore_fico                                 -0.178
# inadimplencia_2_anos                         1.000
# registros_publicos_negativos                -0.021
# renda_mensal                                 0.033
#
#                               registros_publicos_negativos  renda_mensal
# valor_financiado                                    -0.055         0.257
# taxa_juros                                           0.052        -0.082
# valor_parcela                                       -0.049         0.248
# tempo_relacionamento                                 0.063         0.119
# escore_fico                                         -0.184         0.048
# inadimplencia_2_anos                                -0.021         0.033
# registros_publicos_negativos                         1.000        -0.009
# renda_mensal                                        -0.009         1.000

# %%
nomes_variaveis = {
    "valor_financiado": "Valor Financiado",
    "taxa_juros": "Taxa de Juros",
    "valor_parcela": "Valor da Parcela",
    "tempo_relacionamento": "Tempo de Relacionamento",
    "escore_fico": "Escore FICO",
    "inadimplencia_2_anos": "Inadimplência (2 anos)",
    "registros_publicos_negativos": "Registros Públicos Negativos",
    "renda_mensal": "Renda Mensal"
}

matriz_corr = matriz_corr.rename(index=nomes_variaveis, columns=nomes_variaveis)

plt.figure(figsize=(10,8))

sns.heatmap(
    matriz_corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    vmin=-1,      # limite inferior
    vmax=1,       # limite superior
    center=0,
    square=True,
    cbar_kws={"label": "Correlação de Pearson"}
)

plt.title("Matriz de Correlação das Variáveis Explicativas Numéricas")
plt.tight_layout()
plt.savefig('figuras/matriz_correlacao_variaveis_numericas.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
print(type(matriz_corr))
# Out:
# <class 'pandas.DataFrame'>
